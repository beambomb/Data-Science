# %% [markdown]
# <a href="https://colab.research.google.com/github/beambomb/Data-Science/blob/main/analysis_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("sales_data.csv")
data.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# Descriptive Statistics Info

# %%
data.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
data.shape
# Out:
# (113036, 18)

# %% [markdown]
# Youngest Customer

# %%
print(min(data['Customer_Age']))
# Out:
# 17

# %% [markdown]
# Oldest Customer

# %%
print(max(data['Customer_Age']))
# Out:
# 87

# %% [markdown]
# Female vs Male Customers

# %%
print("Male Customer : ",(data['Customer_Gender'] == 'M').sum())
print("Female Customer : ",(data['Customer_Gender'] == "F").sum())
# Out:
# Male Customer :  58312
# Female Customer :  54724

# %%
data.groupby('Product_Category')['Profit'].sum()
# Out:
# Product_Category
# Accessories     8862377
# Bikes          20519276
# Clothing        2839447
# Name: Profit, dtype: int64

# %%
data.groupby('Product_Category')['Profit'].count()
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: Unit_Cost, dtype: int64

# %%
data.groupby('Country')['Order_Quantity'].sum()
# Out:
# Country
# Australia         263585
# Canada            192259
# France            128995
# Germany           125720
# United Kingdom    157218
# United States     477539
# Name: Order_Quantity, dtype: int64

# %% [markdown]
# Checking Zero Value from the Dataset

# %%
data.isnull().sum()
# Out:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64
